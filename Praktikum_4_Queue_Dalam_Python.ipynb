# %% [markdown]
# <a href="https://colab.research.google.com/github/kyaadevi/Praktkum-Sturktur-Data/blob/main/Praktikum_4_Queue_Dalam_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Queue dengan List

# %%
queue = []

queue.append('a')
queue.append('i')
queue.append('u')
queue.append('e')
queue.append('o')

print("Initial queue")
print(queue)

print("\nElements dequeued from queue")
print(queue.pop(0))
print(queue.pop(0))
print(queue.pop(0))

print("\nQueue after removing elements")
print(queue)
# Out:
# Initial queue
# ['a', 'i', 'u', 'e', 'o']
#
# Elements dequeued from queue
# a
# i
# u
#
# Queue after removing elements
# ['e', 'o']

# %% [markdown]
# Queue dengan collections.deque

# %%
from collections import deque

queue = deque()

queue.append(1)
queue.append(2)
queue.append(3)
queue.append(4)
queue.append(5)

print('initial queue')
print(queue)

print('\nElements dequeued from queue')
print(queue.popleft())
print(queue.popleft())
print(queue.popleft())

print('\nQueue after removing elements')
print(queue)
# Out:
# initial queue
# deque([1, 2, 3, 4, 5])
#
# Elements dequeued from queue
# 1
# 2
# 3
# 4
#
# Queue after removing elements
# deque([5])

# %% [markdown]
# Queue dengan queue.Queue

# %%
from queue import Queue

qu = Queue(maxsize=5)
print(qu.qsize())

qu.put(1)
qu.put(2)
qu.put(3)
qu.put(4)
qu.put(5)

print("full: ", qu.full())
print("size: ", qu.qsize())

print('\nElements dequeued from queue')
print(qu.get())
print(qu.get())
print(qu.get())

print("\nEmpty: ", qu.empty())
print("Full: ", qu.full())
# Out:
# 0
# full:  True
# size:  5
#
# Elements dequeued from queue
# 1
# 2
# 3
#
# Empty:  False
# Full:  False

# %% [markdown]
# Queue dengan Single Linked List

# %%
class Queue:
  def __init__(self):
    self.queue = list()

  def addtoqu(self,dataval):
    if dataval not in self.queue:
      self.queue.insert(0,dataval)
      return True
    return False

  def removefromq(self):
    if len(self.queue)>0:
      return self.queue.pop()
    return ("No elements in Queue!")

  def size(self):
    return len(self.queue)

TheQueue = Queue()
print(TheQueue.addtoqu("Mon"))
print(TheQueue.addtoqu("Tue"))
print(TheQueue.addtoqu("Wed"))
print(TheQueue.addtoqu("Fri"))
print(TheQueue.size())
print(TheQueue.removefromq())
print(TheQueue.removefromq())
print(TheQueue.size())
# Out:
# True
# True
# True
# True
# 4
# Mon
# Tue
# 2
